# %% [markdown]
# # Iris Çiçek Sınıflandırma
#
# Bu projede çiçeğin yaprak ölçüleriyle türünü tahmin edeceğim. Klasik bir set, 3 sınıf var.

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Data

# %%
df=pd.read_csv('data/IRIS.csv')
df.head()

# %% [markdown]
# ### EDA

# %%
df.info()
df.isnull().sum()

# %%
df['species'].value_counts()

# %% [markdown]
# ### Görselleştirme

# %%
sns.pairplot(df,hue='species')
plt.show()

# %% [markdown]
# ### Boş veri

# %%
df=df.fillna(df.median(numeric_only=True))

# %% [markdown]
# ### Feature Engineering

# %%
x=df.drop('species',axis=1)
y=df['species']

# %% [markdown]
# ### Train Test Split

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42,stratify=y)

# %% [markdown]
# ### Modelling

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score,classification_report

# %%
log=LogisticRegression(max_iter=200)
log.fit(x_train,y_train)
print('LogReg',accuracy_score(y_test,log.predict(x_test)))

# %%
knn=KNeighborsClassifier()
knn.fit(x_train,y_train)
print('KNN',accuracy_score(y_test,knn.predict(x_test)))

# %%
rf=RandomForestClassifier(random_state=42)
rf.fit(x_train,y_train)
print('RF',accuracy_score(y_test,rf.predict(x_test)))

# %%
rf=RandomForestClassifier(random_state=42)
rf.fit(x_train,y_train)
print(classification_report(y_test,rf.predict(x_test)))

# %%
import joblib
joblib.dump(rf,'../../models/classification_iris.joblib')

# %% [markdown]
# ### Sonuç
#
# Pairplot'ta setosa ayrı duruyor. KNN ve RF ikisi de yüksek çıktı, raporu RF üzerinden baktım.

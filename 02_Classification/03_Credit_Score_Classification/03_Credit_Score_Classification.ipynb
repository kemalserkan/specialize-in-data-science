# %% [markdown]
# # Kredi Riski Sınıflandırma
#
# Bu projede Alman kredi verisine bakarak müşterinin riskli olup olmadığını tahmin edeceğim.

# %%
import pandas as pd
pd.set_option('display.max_columns',100)
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Data

# %%
df=pd.read_csv('data/german_credit.csv')
df.head()

# %% [markdown]
# ### EDA

# %%
df.info()

# %%
df.isnull().sum()

# %%
df['credit_risk'].value_counts()

# %% [markdown]
# ### Görselleştirme

# %%
sns.boxplot(x='credit_risk',y='amount',data=df)
plt.show()

# %%
sns.histplot(df['age'],bins=20)
plt.show()

# %% [markdown]
# ### Boş veri

# %%
df['amount']=df['amount'].fillna(df['amount'].median())
df['age']=df['age'].fillna(df['age'].median())

# %% [markdown]
# ### Feature Engineering

# %%
x=df.drop('credit_risk',axis=1)
y=df['credit_risk']
x=pd.get_dummies(x,drop_first=True)

# %% [markdown]
# ### Train Test Split

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42,stratify=y)

# %% [markdown]
# ### 3 Model

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score,classification_report

for ad,m in [('LogReg',LogisticRegression(max_iter=300)),('DT',DecisionTreeClassifier(random_state=42)),('RF',RandomForestClassifier(random_state=42))]:
    m.fit(x_train,y_train)
    print(ad,accuracy_score(y_test,m.predict(x_test)))

# %%
rf=RandomForestClassifier(random_state=42)
rf.fit(x_train,y_train)
print(classification_report(y_test,rf.predict(x_test)))

# %%
import joblib
joblib.dump(rf,'../../models/classification_credit_score.joblib')

# %% [markdown]
# ### Sonuç
#
# German Credit setinde sınıflar dengesiz. RF daha düzgün çalıştı. Hedefi kısmen tutturdum, riskli müşteriyi yakalamak için recall'a bakmak lazım.
